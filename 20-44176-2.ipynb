# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
from PIL import Image
from sklearn.model_selection import train_test_split
import random
import pickle
from tqdm import tqdm
import glob

# %%
TRAIN_DIR = 'D:/CIFAR/CIFAR-10-images-master/train'
CATEGORIES = [c for c in os.listdir(TRAIN_DIR) if os.path.isdir(os.path.join(TRAIN_DIR, c))]
print(CATEGORIES)
# Out:
# ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'test', 'truck']

# %%
img_path = r'D:/CIFAR/CIFAR-10-images-master/train/airplane'
dest_path = r'D:/CIFAR/CIFAR-10-images-master/train/test'

img_path2 = r'D:/CIFAR/CIFAR-10-images-master/train/automobile'
dest_path = r'D:/CIFAR/CIFAR-10-images-master/train/test'

img_path3 = r'D:/CIFAR/CIFAR-10-images-master/train/bird'
dest_path = r'D:/CIFAR/CIFAR-10-images-master/train/test'

img_path4 = r'D:/CIFAR/CIFAR-10-images-master/train/cat'
dest_path = r'D:/CIFAR/CIFAR-10-images-master/train/test'

img_path5 = r'D:/CIFAR/CIFAR-10-images-master/train/deer'
dest_path = r'D:/CIFAR/CIFAR-10-images-master/train/test'

img_path6 = r'D:/CIFAR/CIFAR-10-images-master/train/dog'
dest_path = r'D:/CIFAR/CIFAR-10-images-master/train/test'

img_path7 = r'D:/CIFAR/CIFAR-10-images-master/train/frog'
dest_path = r'D:/CIFAR/CIFAR-10-images-master/train/test'

img_path8 = r'D:/CIFAR/CIFAR-10-images-master/train/horse'
dest_path = r'D:/CIFAR/CIFAR-10-images-master/train/test'

img_path9 = r'D:/CIFAR/CIFAR-10-images-master/train/ship'
dest_path = r'D:/CIFAR/CIFAR-10-images-master/train/test'

img_path10 = r'D:/CIFAR/CIFAR-10-images-master/train/truck'
dest_path = r'D:/CIFAR/CIFAR-10-images-master/train/test'

# %%
i = 1
for img in glob.glob(img_path + '/*.*'):
    try:
        image = cv2.imread(img)
        grayscale = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

        os.chdir(dest_path)
        filename = 'grayscale_Air' + str(i) + '.png'
        cv2.imwrite(filename, grayscale)
        i += 1
    except:
        print('Image not saved')

# %%
i = 1
for img in glob.glob(img_path2 + '/*.*'):
    try:
        image = cv2.imread(img)
        grayscale = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

        os.chdir(dest_path)
        filename = 'grayscale_Auto' + str(i) + '.png'
        cv2.imwrite(filename, grayscale)
        i += 1
    except:
        print('Image not saved')

# %%
i = 1
for img in glob.glob(img_path3 + '/*.*'):
    try:
        image = cv2.imread(img)
        grayscale = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

        os.chdir(dest_path)
        filename = 'grayscale_Bird' + str(i) + '.png'
        cv2.imwrite(filename, grayscale)
        i += 1
    except:
        print('Image not saved')

# %%
i = 1
for img in glob.glob(img_path4 + '/*.*'):
    try:
        image = cv2.imread(img)
        grayscale = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

        os.chdir(dest_path)
        filename = 'grayscale_cat' + str(i) + '.png'
        cv2.imwrite(filename, grayscale)
        i += 1
    except:
        print('Image not saved')

# %%
i = 1
for img in glob.glob(img_path5 + '/*.*'):
    try:
        image = cv2.imread(img)
        grayscale = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

        os.chdir(dest_path)
        filename = 'grayscale_deer' + str(i) + '.png'
        cv2.imwrite(filename, grayscale)
        i += 1
    except:
        print('Image not saved')

# %%
i = 1
for img in glob.glob(img_path6 + '/*.*'):
    try:
        image = cv2.imread(img)
        grayscale = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

        os.chdir(dest_path)
        filename = 'grayscale_frog' + str(i) + '.png'
        cv2.imwrite(filename, grayscale)
        i += 1
    except:
        print('Image not saved')

# %%
i = 1
for img in glob.glob(img_path7 + '/*.*'):
    try:
        image = cv2.imread(img)
        grayscale = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

        os.chdir(dest_path)
        filename = 'grayscale_horse' + str(i) + '.png'
        cv2.imwrite(filename, grayscale)
        i += 1
    except:
        print('Image not saved')

# %%
i = 1
for img in glob.glob(img_path8 + '/*.*'):
    try:
        image = cv2.imread(img)
        grayscale = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

        os.chdir(dest_path)
        filename = 'grayscale_Dog' + str(i) + '.png'
        cv2.imwrite(filename, grayscale)
        i += 1
    except:
        print('Image not saved')

# %%
i = 1
for img in glob.glob(img_path9 + '/*.*'):
    try:
        image = cv2.imread(img)
        grayscale = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

        os.chdir(dest_path)
        filename = 'grayscale_ship' + str(i) + '.png'
        cv2.imwrite(filename, grayscale)
        i += 1
    except:
        print('Image not saved')

# %%
i = 1
for img in glob.glob(img_path10 + '/*.*'):
    try:
        image = cv2.imread(img)
        grayscale = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

        os.chdir(dest_path)
        filename = 'grayscale_Truck' + str(i) + '.png'
        cv2.imwrite(filename, grayscale)
        i += 1
    except:
        print('Image not saved')

# %%
path = 'D:/CIFAR/CIFAR-10-images-master/train/test'
images = [file for file in os.listdir(path) if os.path.isfile(os.path.join(path, file))]

type(images)
len(images)
# Out:
# 55000

# %%
path = 'D:/CIFAR/CIFAR-10-images-master/train/test'
images = [file for file in os.listdir(path) if os.path.isfile(os.path.join(path, file))]

img_data = [cv2.imread(os.path.join(path, img)) for img in images]
img_data = np.array(img_data)

# %%
path = 'D:/CIFAR/CIFAR-10-images-master/train/test'
images = [file for file in os.listdir(path) if os.path.isfile(os.path.join(path, file))]

img_data = []
for img in images:
    img_path = os.path.join(path, img)
    img_array = cv2.imread(img_path)
    img_data.append(img_array)
img_data = np.array(img_data)

plt.figure(figsize=(15, 15))  
for i in range(min(len(img_data), 64)):
    plt.subplot(8, 8, i + 1) 
    plt.imshow(img_data[i])
plt.show()

# %%
TRAIN_DATA = []
for c in CATEGORIES:
    path = os.path.join(TRAIN_DIR, c)
    class_num = CATEGORIES.index(c)
    count = 0  # Track the number of images processed

    for img in tqdm(os.listdir(path)):
        if count >= 500000:  # Limit the number of images to 500,000
            break

        img_arr = cv2.imread(os.path.join(path,img))
        TRAIN_DATA.append([img_arr, class_num])
        count += 1

print(len(TRAIN_DATA))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 3
#       1 TRAIN_DATA = []
#       2 for c in CATEGORIES:
# ----> 3     path = os.path.join(TRAIN_DIR, c)
#       4     class_num = CATEGORIES.index(c)
#       5     count = 0  # Track the number of images processed
#
# File ~\anaconda3\lib\ntpath.py:143, in join(path, *paths)
#     141     return result_drive + result_path
#     142 except (TypeError, AttributeError, BytesWarning):
# --> 143     genericpath._check_arg_types('join', path, *paths)
#     144     raise
#
# File ~\anaconda3\lib\genericpath.py:152, in _check_arg_types(funcname, *args)
#     150         hasbytes = True
#     151     else:
# --> 152         raise TypeError(f'{funcname}() argument must be str, bytes, or '
#     153                         f'os.PathLike object, not {s.__class__.__name__!r}') from None
#     154 if hasstr and hasbytes:
# ...

# %%
num_samples = 1000
f0 = TRAIN_DATA[:num_samples]
f1 = TRAIN_DATA[num_samples:2*num_samples]
f2 = TRAIN_DATA[2*num_samples:3*num_samples]
f3 = TRAIN_DATA[3*num_samples:4*num_samples]
f4 = TRAIN_DATA[4*num_samples:5*num_samples]

# %%
k_max = 10

def l1_dist(x, y):
    return np.sum(np.abs(x - y))

def l2_dist(x, y):
    return np.sqrt(np.sum((x - y) ** 2))

def knn(train, validation, k):
    preds = []
    for v in validation:
        distances = []
        for t in train:
            l2 = l2_dist(v[0], t[0])
            distances.append((l2, t[1]))
        distances.sort(key=lambda x: x[0])
        neighbors = [d[1] for d in distances[:k]]
        counts = np.bincount(neighbors)
        pred = np.argmax(counts)
        preds.append(pred)
    return preds

mean_accuracies_l1 = []
std_accuracies_l1 = []
mean_accuracies_l2 = []
std_accuracies_l2 = []

for k in tqdm(range(1, k_max+1)):
    fold_accuracies_l1 = []
    fold_accuracies_l2 = []
    
    for i in range(5):
        if i == 0:
            train = f1+f2+f3+f4
            validation = f0
        elif i == 1:
            train = f0+f2+f3+f4
            validation = f1
        elif i == 2:
            train = f1+f0+f3+f4
            validation = f2
        elif i == 3:
            train = f1+f2+f0+f4
            validation = f3
        elif i == 4:
            train = f1+f2+f3+f0
            validation = f4

        acc_l1 = 0
        acc_l2 = 0

        for v in validation:
            l1_dists = []
            l2_dists = []
            for t in train:
                l1 = l1_dist(v[0], t[0])
                l2 = l2_dist(v[0], t[0])
                l1_dists.append((l1, t[1]))
                l2_dists.append((l2, t[1]))
            l1_dists.sort(key=lambda x: x[0])
            l2_dists.sort(key=lambda x: x[0])

            neighbors_l1 = [d[1] for d in l1_dists[:k]]
            counts_l1 = np.bincount(neighbors_l1)
            pred_l1 = np.argmax(counts_l1)

            neighbors_l2 = [d[1] for d in l2_dists[:k]]
            counts_l2 = np.bincount(neighbors_l2)
            pred_l2 = np.argmax(counts_l2)

            if pred_l1 == v[1]:
                acc_l1 += 1
            if pred_l2 == v[1]:
                acc_l2 += 1

        fold_accuracies_l1.append(acc_l1 / len(validation))
        fold_accuracies_l2.append(acc_l2 / len(validation))

    mean_accuracies_l1.append(np.mean(fold_accuracies_l1))
    std_accuracies_l1.append(np.std(fold_accuracies_l1))
    mean_accuracies_l2.append(np.mean(fold_accuracies_l2))
    std_accuracies_l2.append(np.std(fold_accuracies_l2))

# Print the mean accuracies and standard deviations for each k
for k in range(k_max):
    print(f"K = {k+1}: L1 Mean Accuracy: {mean_accuracies_l1[k]}, L1 Std Accuracy: {std_accuracies_l1[k]}")
    print(f"K = {k+1}: L2 Mean Accuracy: {mean_accuracies_l2[k]}, L2 Std Accuracy: {std_accuracies_l2[k]}")
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[36], line 76
#      73         if pred_l2 == v[1]:
#      74             acc_l2 += 1
# ---> 76     fold_accuracies_l1.append(acc_l1 / len(validation))
#      77     fold_accuracies_l2.append(acc_l2 / len(validation))
#      79 mean_accuracies_l1.append(np.mean(fold_accuracies_l1))
#
# ZeroDivisionError: division by zero

# %%
plt.errorbar(range(1, k_max + 1, 2), mean_accuracies_l1, yerr=std_accuracies_l1, label="L1 Distance")
plt.errorbar(range(1, k_max + 1, 2), mean_accuracies_l2, yerr=std_accuracies_l2, label="L2 Distance")

plt.xlabel("k")
plt.ylabel("Accuracy")
plt.title("K-NN Accuracy vs. k")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 plt.errorbar(range(1, k_max + 1, 2), mean_accuracies_l1, yerr=std_accuracies_l1, label="L1 Distance")
#       2 plt.errorbar(range(1, k_max + 1, 2), mean_accuracies_l2, yerr=std_accuracies_l2, label="L2 Distance")
#       4 plt.xlabel("k")
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:2537, in errorbar(x, y, yerr, xerr, fmt, ecolor, elinewidth, capsize, barsabove, lolims, uplims, xlolims, xuplims, errorevery, capthick, data, **kwargs)
#    2531 @_copy_docstring_and_deprecators(Axes.errorbar)
#    2532 def errorbar(
#    2533         x, y, yerr=None, xerr=None, fmt='', ecolor=None,
#    2534         elinewidth=None, capsize=None, barsabove=False, lolims=False,
#    2535         uplims=False, xlolims=False, xuplims=False, errorevery=1,
# ...

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Plot for L1 distance
ax1.errorbar(range(1, k_max + 1, 2), mean_accuracies_l1, yerr=std_accuracies_l1, label="L1 Distance", color="red")
ax1.set_xlabel("k")
ax1.set_ylabel("Accuracy")
ax1.set_title("K-NN Accuracy vs. k (L1 Distance)")
ax1.legend()

# Plot for L2 distance
ax2.errorbar(range(1, k_max + 1, 2), mean_accuracies_l2, yerr=std_accuracies_l2, label="L2 Distance", color="green")
ax2.set_xlabel("k")
ax2.set_ylabel("Accuracy")
ax2.set_title("K-NN Accuracy vs. k (L2 Distance)")
ax2.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 4
#       1 fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))
#       3 # Plot for L1 distance
# ----> 4 ax1.errorbar(range(1, k_max + 1, 2), mean_accuracies_l1, yerr=std_accuracies_l1, label="L1 Distance", color="red")
#       5 ax1.set_xlabel("k")
#       6 ax1.set_ylabel("Accuracy")
#
# File ~\anaconda3\lib\site-packages\matplotlib\__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
#    1445     auto_label = (bound.arguments.get(label_namer)
#    1446                   or bound.kwargs.get(label_namer))
#
# ...
